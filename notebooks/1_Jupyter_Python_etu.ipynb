# %% [markdown]
# # Exercises with Python
#
# Lina Khelfet and Stéphane Bourg
#
# This notebook is an adaption from the Python and Jupyter Notebook user guides, see [Python Tutorial](https://docs.python.org/3/tutorial/index.html) and [Jupyter Documentation](https://docs.jupyter.org/en/latest/).

# %% [markdown]
# Replace XXX by the right code

# %% [markdown]
# ## Configuration

# %%
# Import numpy library as the alias np
XXX

# %% [markdown]
# ## Exercise 1: lists

# %%
# Use list() to build a list called my_pets with a = "cat", b = "dog", c= "fish"
a = XXX
b = XXX
c = XXX
my_pets = list(XXX)

# %%
# Print the list
XXX

# %%
# Reverse my_pets
XXX

# %%
# Use a comprehension list with range() to create a list first_even_l of the first 10 even numbers
first_even_l = [x for XXX]

# %%
# Print first_even_l
XXX

# %% [markdown]
# ## Exercise 2: dictionary

# %%
# Nested dictionary
emp_dict = {
    "company": {
        "employee": {
            "name": "Jess",
            "payable": {
                "salary": 9000,
                "increment": 12
            }
        }
    }
}

# %%
# Write command to access increment value
XXX

# %%
# Dictionary
d1 = {'A': 65, 'B': 66, 'C': 67, 'D': 68, 'E': 69, 'F': 70}

# Create a new dictionary new_dict based on the keys defined in the following list l1
l1 = ['A', 'C', 'F']

new_dict = {XXX}
new_dict

# %% [markdown]
# ## Exercise 3: functions

# %%
# Define a function calculation, which takes x as parameter and return ((5 * x) / 2)²
def calculation(XXX):
  return XXX

# %%
# Verify the result of calculation(4)
calculation(4) == 100

# %%
# Define the same function f using a lambda function
f = lambda XXX

# Verify the result of f(4)
print(f(4))
